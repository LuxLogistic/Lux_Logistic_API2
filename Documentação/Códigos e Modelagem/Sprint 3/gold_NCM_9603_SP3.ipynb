# %%
import pandas as pd
import numpy as np
import json

# %%
import pymongo
from pymongo import MongoClient

# %%
# conexão MongoDB
client = MongoClient('mongodb+srv://jehtinoco:TI10co29**@clusterjessica.ejf02eq.mongodb.net/test')

# %%
db=client["dev_comexstat"]

# %%
coll_tab01=db["depara_ncm_isic"]
coll_tab02=db["depara_pais"]
coll_tab03=db["depara_sh4"]
coll_tab04=db["depara_urf_lat_long"]
coll_tab05=db["depara_via"]
coll_tab06=db["depara_unid"]

# %%
pipe_tab01 = [{'$project':{'_id':0, 
                           'CO_NCM': 1,
                           'NO_NCM_POR': 1,
                           'NO_ISIC_SECAO': 1,
                           'NO_ISIC_CLASSE':1 }}]

pipe_tab02 = [{'$project':{'_id':0,
                           'CO_PAIS': 1,
                           'NO_PAIS': 1 }}]

pipe_tab03 = [{'$project':{'_id':0,
                           'CO_SH4': 1,
                           'NO_SH4_POR':1 }}]

pipe_tab04 = [{'$project':{'_id':0, 
                           'CO_URF': 1,
                           'NO_URF2': 1,
                           'LAT': 1,
                           'LONG': 1 }}]

pipe_tab05 = [{'$project':{'_id':0, 
                           'CO_VIA': 1,
                           'NO_VIA': 1 }}]

pipe_tab06 = [{'$project':{'_id':0,
                           'CO_UNID': 1,
                           'SG_UNID':1 }}]

# %%
cursor_tab01=coll_tab01.aggregate(pipe_tab01)
cursor_tab02=coll_tab02.aggregate(pipe_tab02)
cursor_tab03=coll_tab03.aggregate(pipe_tab03)
cursor_tab04=coll_tab04.aggregate(pipe_tab04)
cursor_tab05=coll_tab05.aggregate(pipe_tab05)
cursor_tab06=coll_tab06.aggregate(pipe_tab06)

# %%
list_tab01=list(cursor_tab01)
list_tab02=list(cursor_tab02)
list_tab03=list(cursor_tab03)
list_tab04=list(cursor_tab04)
list_tab05=list(cursor_tab05)
list_tab06=list(cursor_tab06)

# %%
df_tab01=pd.DataFrame(list_tab01)
df_tab02=pd.DataFrame(list_tab02)
df_tab03=pd.DataFrame(list_tab03)
df_tab04=pd.DataFrame(list_tab04)
df_tab05=pd.DataFrame(list_tab05)
df_tab06=pd.DataFrame(list_tab06)

# %%
base_imp_NCM=r"C:\Users\jetin\Documents\FATEC\2° semestre\api2\Dados\IMP_2023.csv"
base_exp_NCM=r"C:\Users\jetin\Documents\FATEC\2° semestre\api2\Dados\EXP_2023.csv"

# %%
dict_type={'CO_ANO':'category',
           'CO_MES':'category',
           'CO_NCM':'category',
           'CO_UNID':'category',
           'CO_PAIS':'category',
           'SG_UF_NCM':'category',
           'CO_VIA':'category',
           'CO_URF':'category',
           'SH4':'category',
           'CO_MUN':'category' }

# %%
df_imp_NCM=pd.read_csv(base_imp_NCM, sep=";", dtype=dict_type)
df_exp_NCM=pd.read_csv(base_exp_NCM, sep=";", dtype=dict_type)

# %% [markdown]
# # Separando o estado de SP e concatenando importação e exportação

# %%
df_imp_NCM['TIPO'] = 'IMPORTAÇÃO'

# %%
df_imp_sp=df_imp_NCM.loc[df_imp_NCM['SG_UF_NCM']=='SP']

# %%
df_imp_sp.head()
# Out:
#   CO_ANO CO_MES    CO_NCM CO_UNID CO_PAIS SG_UF_NCM CO_VIA   CO_URF  QT_ESTAT  \
# 0   2023     01  85299040      10     355        SP     04  0817600         1
# 1   2023     01  84818093      11     386        SP     01  0817800      7400
# 2   2023     06  85389090      10     365        SP     04  0817700        27
# 4   2023     03  29199090      10     023        SP     04  0817700      1821
# 5   2023     01  84831090      11     160        SP     01  0817800    783395
#
#    KG_LIQUIDO  VL_FOB  VL_FRETE  VL_SEGURO        TIPO
# 0           1     968        15          0  IMPORTAÇÃO
# 1        4233  101402       890         86  IMPORTAÇÃO
# 2          27   20341       443          1  IMPORTAÇÃO
# 4        1821   29799     11638         10  IMPORTAÇÃO
# 5      118684  957092     44280        488  IMPORTAÇÃO

# %%
df_exp_NCM['TIPO'] = 'EXPORTAÇÃO'

# %%
df_exp_sp=df_exp_NCM.loc[df_exp_NCM['SG_UF_NCM']=='SP']

# %%
df_exp_sp.head()
# Out:
#    CO_ANO CO_MES    CO_NCM CO_UNID CO_PAIS SG_UF_NCM CO_VIA   CO_URF  \
# 1    2023     01  85114000      11     756        SP     01  0817800
# 4    2023     02  84812090      11     063        SP     04  0817600
# 5    2023     03  28181090      10     827        SP     01  0817800
# 7    2023     05  09103000      10     741        SP     01  0817800
# 13   2023     05  41071220      15     249        SP     04  0817600
#
#     QT_ESTAT  KG_LIQUIDO  VL_FOB        TIPO
# 1         60         548   13994  EXPORTAÇÃO
# 4        422         115   48432  EXPORTAÇÃO
# 5     108000      108000  137600  EXPORTAÇÃO
# 7          3           3      17  EXPORTAÇÃO
# 13     10691       10020  151999  EXPORTAÇÃO

# %%
df_concat_sp=pd.concat([df_imp_sp,df_exp_sp]).reset_index(drop=True)

# %%
df_concat_sp.head()
# Out:
#   CO_ANO CO_MES    CO_NCM CO_UNID CO_PAIS SG_UF_NCM CO_VIA   CO_URF  QT_ESTAT  \
# 0   2023     01  85299040      10     355        SP     04  0817600         1
# 1   2023     01  84818093      11     386        SP     01  0817800      7400
# 2   2023     06  85389090      10     365        SP     04  0817700        27
# 3   2023     03  29199090      10     023        SP     04  0817700      1821
# 4   2023     01  84831090      11     160        SP     01  0817800    783395
#
#    KG_LIQUIDO  VL_FOB  VL_FRETE  VL_SEGURO        TIPO
# 0           1     968      15.0        0.0  IMPORTAÇÃO
# 1        4233  101402     890.0       86.0  IMPORTAÇÃO
# 2          27   20341     443.0        1.0  IMPORTAÇÃO
# 3        1821   29799   11638.0       10.0  IMPORTAÇÃO
# 4      118684  957092   44280.0      488.0  IMPORTAÇÃO

# %% [markdown]
# ## Aplicando depara na base SP

# %%
#inserindo cod_sh4 pelo cod_ncm
df_concat_sp['CO_SH4']=[numero[0:4] for numero in df_concat_sp['CO_NCM']]

# %%
df_concat_sp.head()
# Out:
#   CO_ANO CO_MES    CO_NCM CO_UNID CO_PAIS SG_UF_NCM CO_VIA   CO_URF  QT_ESTAT  \
# 0   2023     01  85299040      10     355        SP     04  0817600         1
# 1   2023     01  84818093      11     386        SP     01  0817800      7400
# 2   2023     06  85389090      10     365        SP     04  0817700        27
# 3   2023     03  29199090      10     023        SP     04  0817700      1821
# 4   2023     01  84831090      11     160        SP     01  0817800    783395
#
#    KG_LIQUIDO  VL_FOB  VL_FRETE  VL_SEGURO        TIPO CO_SH4
# 0           1     968      15.0        0.0  IMPORTAÇÃO   8529
# 1        4233  101402     890.0       86.0  IMPORTAÇÃO   8481
# 2          27   20341     443.0        1.0  IMPORTAÇÃO   8538
# 3        1821   29799   11638.0       10.0  IMPORTAÇÃO   2919
# 4      118684  957092   44280.0      488.0  IMPORTAÇÃO   8483

# %% [markdown]
# #### Preparando depara SH4 para aplicar na base

# %%
#procurando nulos no depara sh4
df_tab03=df_tab03.loc[df_tab03['CO_SH4'].notnull()]

# %%
#contando numeros nulos cod_sh4
df_tab03.duplicated(subset=['CO_SH4']).sum()
# Out:
# 0

# %%
df_merge1=pd.merge(df_concat_sp, df_tab04, how='left', on='CO_URF')

# %%
df_merge2=pd.merge(df_merge1, df_tab03, how='left', on='CO_SH4')

# %%
df_merge3=pd.merge(df_merge2, df_tab02, how='left', on='CO_PAIS')

# %% [markdown]
# #### Preparando depara UNID para aplicar na base

# %%
df_tab06.duplicated(subset=['CO_UNID']).sum()
# Out:
# 13617

# %%
chave_tab06=['CO_UNID', 'SG_UNID']

df_unids=df_tab06.groupby(chave_tab06).sum().reset_index()

# %%
df_merge4=pd.merge(df_merge3, df_unids, how='left', on='CO_UNID')

# %%
df_merge5=pd.merge(df_merge4, df_tab01, how='left', on='CO_NCM')

# %%
df_merge6=pd.merge(df_merge5, df_tab05, how='left', on='CO_VIA')

# %% [markdown]
# #### Limpando base SP

# %%
df_sp=df_merge6.drop(['CO_UNID', 'CO_PAIS', 'CO_URF', 'CO_VIA','QT_ESTAT','VL_FRETE','VL_SEGURO' ], axis=1)

# %%
df_sp.insert(5,'NO_NCM_POR', df_sp.pop('NO_NCM_POR'))
df_sp.insert(6,'NO_ISIC_SECAO', df_sp.pop('NO_ISIC_SECAO'))
df_sp.insert(7,'NO_ISIC_CLASSE', df_sp.pop('NO_ISIC_CLASSE'))
df_sp.insert(2,'CO_SH4', df_sp.pop('CO_SH4'))
df_sp.insert(3,'NO_SH4_POR', df_sp.pop('NO_SH4_POR'))
df_sp.insert(13,'NO_PAIS', df_sp.pop('NO_PAIS'))
df_sp.insert(15,'SG_UNID', df_sp.pop('SG_UNID'))
df_sp.insert(8,'SG_UF_NCM', df_sp.pop('SG_UF_NCM'))
df_sp.insert(9,'NO_URF2', df_sp.pop('NO_URF2'))
df_sp.insert(10,'LAT', df_sp.pop('LAT'))
df_sp.insert(11,'LONG', df_sp.pop('LONG'))
df_sp.insert(14,'NO_VIA', df_sp.pop('NO_VIA'))
df_sp.insert(16,'KG_LIQUIDO', df_sp.pop('KG_LIQUIDO'))

# %%
df_sp.head()
# Out:
#   CO_ANO CO_MES CO_SH4                                         NO_SH4_POR  \
# 0   2023     01   8529  Partes reconhecíveis como exclusiva ou princip...
# 1   2023     01   8481  Torneiras; válvulas (incluídas as redutoras de...
# 2   2023     06   8538  Partes reconhecíveis como exclusiva ou princip...
# 3   2023     03   2919  Ésteres fosfóricos e seus sais; incluindo os l...
# 4   2023     01   8483  Veios (árvores) de transmissão [incluídas as á...
#
#      CO_NCM                                         NO_NCM_POR  \
# 0  85299040     Outras partes para aparelhos de radionavegação
# 1  84818093                               Válvulas tipo gaveta
# 2  85389090  Outras partes para aparelhos de interrupção de...
# 3  29199090  Outros ésteres fosfóricos e seus sais, incluin...
# 4  84831090              Outras árvores (veios) de transmissão
#
#                 NO_ISIC_SECAO SG_UF_NCM  \
# 0  Indústria de Transformação        SP
# 1  Indústria de Transformação        SP
# 2  Indústria de Transformação        SP
# 3  Indústria de Transformação        SP
# 4  Indústria de Transformação        SP
#
#                                           NO_URF2        LAT       LONG  \
# 0  AEROPORTO INTERNACIONAL DE SAO PAULO/GUARULHOS -23.430573 -46.473043
# 1                                 PORTO DE SANTOS -23.966041 -46.301944
# 2            AEROPORTO INTERNACIONAL DE VIRACOPOS -23.008205 -47.137569
# 3            AEROPORTO INTERNACIONAL DE VIRACOPOS -23.008205 -47.137569
# 4                                 PORTO DE SANTOS -23.966041 -46.301944
#
#                                       NO_ISIC_CLASSE  VL_FOB    NO_VIA  \
# 0      Fabricação de produtos eletrônicos de consumo     968     AEREA
# 1  Fabricação de outras bombas, compressores, tor...  101402  MARITIMA
# 2  Fabricação de motores elétricos, geradores, tr...   20341     AEREA
# 3            Fabricação de produtos químicos básicos   29799     AEREA
# 4  Fabricação de rolamentos, engrenagens, engrena...  957092  MARITIMA
#
#          TIPO    NO_PAIS  KG_LIQUIDO SG_UNID
# 0  IMPORTAÇÃO    Hungria           1   KGL
# 1  IMPORTAÇÃO     Itália        4233   UNID.
# 2  IMPORTAÇÃO  Indonésia          27   KGL
# 3  IMPORTAÇÃO   Alemanha        1821   KGL
# 4  IMPORTAÇÃO      China      118684   UNID.

# %% [markdown]
# ## Incluindo as cadeias produtivas e criando base SP-NCM-URF

# %%
# Ler o arquivo de mapeamento em formato JSON
with open('mapeamento.json', 'r', encoding='utf-8') as arquivo:
    mapeamento = json.load(arquivo)

# %%
df_sp['CADEIA PRODUTIVA'] = df_sp['CO_SH4'].map(mapeamento)

# %%
df_sp['CADEIA PRODUTIVA'] = df_sp['CADEIA PRODUTIVA'].fillna('Outras')

# %%
df_sp.head()
# Out:
#   CO_ANO CO_MES CO_SH4                                         NO_SH4_POR  \
# 0   2023     01   8529  Partes reconhecíveis como exclusiva ou princip...
# 1   2023     01   8481  Torneiras; válvulas (incluídas as redutoras de...
# 2   2023     06   8538  Partes reconhecíveis como exclusiva ou princip...
# 3   2023     03   2919  Ésteres fosfóricos e seus sais; incluindo os l...
# 4   2023     01   8483  Veios (árvores) de transmissão [incluídas as á...
#
#      CO_NCM                                         NO_NCM_POR  \
# 0  85299040     Outras partes para aparelhos de radionavegação
# 1  84818093                               Válvulas tipo gaveta
# 2  85389090  Outras partes para aparelhos de interrupção de...
# 3  29199090  Outros ésteres fosfóricos e seus sais, incluin...
# 4  84831090              Outras árvores (veios) de transmissão
#
#                 NO_ISIC_SECAO SG_UF_NCM  \
# 0  Indústria de Transformação        SP
# 1  Indústria de Transformação        SP
# 2  Indústria de Transformação        SP
# 3  Indústria de Transformação        SP
# 4  Indústria de Transformação        SP
#
#                                           NO_URF2        LAT       LONG  \
# 0  AEROPORTO INTERNACIONAL DE SAO PAULO/GUARULHOS -23.430573 -46.473043
# 1                                 PORTO DE SANTOS -23.966041 -46.301944
# 2            AEROPORTO INTERNACIONAL DE VIRACOPOS -23.008205 -47.137569
# 3            AEROPORTO INTERNACIONAL DE VIRACOPOS -23.008205 -47.137569
# 4                                 PORTO DE SANTOS -23.966041 -46.301944
#
#                                       NO_ISIC_CLASSE  VL_FOB    NO_VIA  \
# 0      Fabricação de produtos eletrônicos de consumo     968     AEREA
# 1  Fabricação de outras bombas, compressores, tor...  101402  MARITIMA
# 2  Fabricação de motores elétricos, geradores, tr...   20341     AEREA
# 3            Fabricação de produtos químicos básicos   29799     AEREA
# 4  Fabricação de rolamentos, engrenagens, engrena...  957092  MARITIMA
#
#          TIPO    NO_PAIS  KG_LIQUIDO SG_UNID     CADEIA PRODUTIVA
# 0  IMPORTAÇÃO    Hungria           1   KGL             Automotiva
# 1  IMPORTAÇÃO     Itália        4233   UNID.          Metalúrgica
# 2  IMPORTAÇÃO  Indonésia          27   KGL    Materiais Elétricos
# 3  IMPORTAÇÃO   Alemanha        1821   KGL           Farmacêutica
# 4  IMPORTAÇÃO      China      118684   UNID.           Automotiva

# %%
df_sp['CADEIA PRODUTIVA'].isna().sum()
# Out:
# 0

# %%
df_sp['CADEIA PRODUTIVA'].value_counts()
# Out:
# Materiais Elétricos              98531
# Metalúrgica                      98171
# Automotiva                       74988
# Alimentar                        73159
# Aparelhos Eletrônicos            65118
# Minério                          63465
# Têxtil                           58092
# Farmacêutica                     40772
# Produtos Químicos Inorgânicos    33838
# Plástico                         31796
# Cosmética                        17723
# Produtos Químicos                17647
# Papel e Celulose                 16239
# Hospitalar                       12860
# Produtos Químicos Orgânicos      12537
# Vidreira                         10732
# Cultura e Entretenimento          8369
# Instrumentos Musicais             7870
# Artigos Domésticos                5185
# Petroleira                        4572
# Calçado                           4535
# Cerâmica                          4208
# Moveleira                         3917
# Agronegócio                       3322
# Ótica                             3143
# Construção Civil                  2961
# Bebidas                           2613
# Petroquímica                      2599
# Aeronáutica                       1781
# Relojoeira                        1550
# Construção civil                  1447
# Telecomunicações                  1124
# Tabacaria                          645
# Farmacéutica                       493
# Pesqueira                          416
# Transporte                         277
# Bélica                             244
# Madeireira                         121
# Minérios                           103
# Name: CADEIA PRODUTIVA, dtype: int64

# %%
# salvando base SP - NCM - URF
df_sp.to_csv('base_SP_NCM_URF.csv', index=False)

# %% [markdown]
# ### Separando base "Outras" da Cadeia Produtiva para mapeamento

# %%
#df_CP_Outras = df_sp.loc[df_sp['CADEIA PRODUTIVA']=='Outras'].reset_index(drop=True)

# %%
#df_CP_Outras=df_CP_Outras[['CO_SH4', 'NO_SH4_POR', 'TIPO', 'CADEIA PRODUTIVA']].drop_duplicates().reset_index(drop=True)

# %%
#df_CP_Outras.head()

# %%
# salvando base Outras Cadeias Produtivas - SH4
#df_CP_Outras.to_csv('base_OUTRAS_CP.csv')

# %% [markdown]
# ## Escolhendo o produto para fluxo logístico de exportação do produto 9603 por URF

# %%
df_9306 = df_sp[(df_sp['TIPO'] == 'EXPORTAÇÃO') & (df_sp['CO_SH4'] == '9306')].reset_index(drop=True)

# %%
df_9306.head()
# Out:
#   CO_ANO CO_MES CO_SH4                                         NO_SH4_POR  \
# 0   2023     05   9306  Bombas; granadas; torpedos; minas; mísseis; ca...
# 1   2023     05   9306  Bombas; granadas; torpedos; minas; mísseis; ca...
# 2   2023     02   9306  Bombas; granadas; torpedos; minas; mísseis; ca...
# 3   2023     03   9306  Bombas; granadas; torpedos; minas; mísseis; ca...
# 4   2023     04   9306  Bombas; granadas; torpedos; minas; mísseis; ca...
#
#      CO_NCM                                         NO_NCM_POR  \
# 0  93062100  Cartuchos para espingardas ou carabinas de can...
# 1  93062100  Cartuchos para espingardas ou carabinas de can...
# 2  93062100  Cartuchos para espingardas ou carabinas de can...
# 3  93062100  Cartuchos para espingardas ou carabinas de can...
# 4  93062100  Cartuchos para espingardas ou carabinas de can...
#
#                 NO_ISIC_SECAO SG_UF_NCM  \
# 0  Indústria de Transformação        SP
# 1  Indústria de Transformação        SP
# 2  Indústria de Transformação        SP
# 3  Indústria de Transformação        SP
# 4  Indústria de Transformação        SP
#
#                                           NO_URF2        LAT       LONG  \
# 0                                 PORTO DE SANTOS -23.966041 -46.301944
# 1                                 PORTO DE SANTOS -23.966041 -46.301944
# 2                                 PORTO DE SANTOS -23.966041 -46.301944
# 3  AEROPORTO INTERNACIONAL DE SAO PAULO/GUARULHOS -23.430573 -46.473043
# 4  AEROPORTO INTERNACIONAL DE SAO PAULO/GUARULHOS -23.430573 -46.473043
#
#                    NO_ISIC_CLASSE    VL_FOB    NO_VIA        TIPO  \
# 0  Fabricação de armas e munições  15969253  MARITIMA  EXPORTAÇÃO
# 1  Fabricação de armas e munições  11453234  MARITIMA  EXPORTAÇÃO
# 2  Fabricação de armas e munições    226929  MARITIMA  EXPORTAÇÃO
# 3  Fabricação de armas e munições    100853     AEREA  EXPORTAÇÃO
# 4  Fabricação de armas e munições     99680     AEREA  EXPORTAÇÃO
#
#                   NO_PAIS  KG_LIQUIDO SG_UNID CADEIA PRODUTIVA
# 0  Emirados Árabes Unidos     1419549   KGL             Bélica
# 1          Estados Unidos      731784   KGL             Bélica
# 2                  Suécia       16120   KGL             Bélica
# 3       Tcheca; República        1091   KGL             Bélica
# 4                   Chile        2710   KGL             Bélica

# %% [markdown]
# ### Tratamento da base histórica do produto

# %%
base_hist_9306=r"C:\Users\jetin\Python_Códigos\API2_fluxo_logistico\Sprint 2\hist_export_ncm.csv"

# %%
dict_type={'CO_ANO':'category',
           'CO_MES':'category',
           'CO_NCM':'category',
           'CO_UNID':'category',
           'CO_PAIS':'category',
           'SG_UF_NCM':'category',
           'CO_VIA':'category',
           'CO_URF':'category',
           'SH4':'category',
           'CO_MUN':'category' }

# %%
df_hist_9306=pd.read_csv(base_hist_9306, sep=",", dtype=dict_type)

# %%
df_hist_9306.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4643 entries, 0 to 4642
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CO_ANO      4643 non-null   category
#  1   CO_MES      4643 non-null   category
#  2   CO_NCM      4643 non-null   category
#  3   CO_PAIS     4643 non-null   category
#  4   CO_UNID     4643 non-null   category
#  5   CO_URF      4643 non-null   category
#  6   CO_VIA      4643 non-null   category
#  7   KG_LIQUIDO  4643 non-null   int64
#  8   QT_ESTAT    4643 non-null   int64
#  9   SG_UF_NCM   4643 non-null   category
#  10  VL_FOB      4643 non-null   int64
# dtypes: category(8), int64(3)
# memory usage: 153.0 KB

# %%
df_hist_9306['TIPO'] = 'EXPORTAÇÃO'

# %%
#inserindo cod_sh4 pelo cod_ncm
df_hist_9306['CO_SH4']=[numero[0:4] for numero in df_hist_9306['CO_NCM']]

# %%
df_merge1=pd.merge(df_hist_9306, df_tab04, how='left', on='CO_URF')

# %%
df_merge2=pd.merge(df_merge1, df_tab03, how='left', on='CO_SH4')

# %%
df_merge3=pd.merge(df_merge2, df_tab02, how='left', on='CO_PAIS')

# %%
df_merge4=pd.merge(df_merge3, df_unids, how='left', on='CO_UNID')

# %%
df_merge5=pd.merge(df_merge4, df_tab01, how='left', on='CO_NCM')

# %%
df_merge6=pd.merge(df_merge5, df_tab05, how='left', on='CO_VIA')

# %%
df_merge6.head(2)
# Out:
#   CO_ANO CO_MES    CO_NCM CO_PAIS CO_UNID   CO_URF CO_VIA  KG_LIQUIDO  \
# 0   1997     07  93062100     275      10  0817800     01        9576
# 1   1997     03  93062100     063      10  0817800     01        3958
#
#    QT_ESTAT SG_UF_NCM  ...          NO_URF2        LAT       LONG  \
# 0         0        SP  ...  PORTO DE SANTOS -23.966041 -46.301944
# 1         0        SP  ...  PORTO DE SANTOS -23.966041 -46.301944
#
#                                           NO_SH4_POR    NO_PAIS  SG_UNID  \
# 0  Bombas; granadas; torpedos; minas; mísseis; ca...     França    KGL
# 1  Bombas; granadas; torpedos; minas; mísseis; ca...  Argentina    KGL
#
#                                           NO_NCM_POR  \
# 0  Cartuchos para espingardas ou carabinas de can...
# 1  Cartuchos para espingardas ou carabinas de can...
#
#                    NO_ISIC_CLASSE               NO_ISIC_SECAO    NO_VIA
# 0  Fabricação de armas e munições  Indústria de Transformação  MARITIMA
# 1  Fabricação de armas e munições  Indústria de Transformação  MARITIMA
#
# [2 rows x 23 columns]

# %% [markdown]
# #### Limpando base histórica

# %%
df_hist_9306=df_merge6.drop(['CO_UNID', 'CO_PAIS', 'CO_URF', 'CO_VIA','QT_ESTAT'], axis=1)

# %%
df_hist_9306.insert(5,'NO_NCM_POR', df_hist_9306.pop('NO_NCM_POR'))
df_hist_9306.insert(6,'NO_ISIC_SECAO', df_hist_9306.pop('NO_ISIC_SECAO'))
df_hist_9306.insert(7,'NO_ISIC_CLASSE', df_hist_9306.pop('NO_ISIC_CLASSE'))
df_hist_9306.insert(2,'CO_SH4', df_hist_9306.pop('CO_SH4'))
df_hist_9306.insert(3,'NO_SH4_POR', df_hist_9306.pop('NO_SH4_POR'))
df_hist_9306.insert(13,'NO_PAIS', df_hist_9306.pop('NO_PAIS'))
df_hist_9306.insert(15,'SG_UNID', df_hist_9306.pop('SG_UNID'))
df_hist_9306.insert(8,'SG_UF_NCM', df_hist_9306.pop('SG_UF_NCM'))
df_hist_9306.insert(9,'NO_URF2', df_hist_9306.pop('NO_URF2'))
df_hist_9306.insert(10,'LAT', df_hist_9306.pop('LAT'))
df_hist_9306.insert(11,'LONG', df_hist_9306.pop('LONG'))
df_hist_9306.insert(14,'NO_VIA', df_hist_9306.pop('NO_VIA'))
df_hist_9306.insert(16,'KG_LIQUIDO', df_hist_9306.pop('KG_LIQUIDO'))

# %% [markdown]
# ### Incluindo as cadeias produtivas

# %%
df_hist_9306['CADEIA PRODUTIVA'] = df_hist_9306['CO_SH4'].map(mapeamento)

# %%
df_hist_9306['CADEIA PRODUTIVA'] = df_hist_9306['CADEIA PRODUTIVA'].fillna('Outras')

# %%
df_hist_9306['CADEIA PRODUTIVA'].isna().sum()
# Out:
# 0

# %%
df_hist_9306['CADEIA PRODUTIVA'].value_counts()
# Out:
# Bélica    4643
# Name: CADEIA PRODUTIVA, dtype: int64

# %% [markdown]
# #### Concatenando base cliente + historico 9603 - produto exportação SJC

# %%
if df_9306.columns.equals(df_hist_9306.columns):
    # Use pd.concat para concatenar os DataFrames
    df_concat_9306 = pd.concat([df_9306, df_hist_9306], ignore_index=True)
else:
    print("Os DataFrames têm estruturas de colunas diferentes.")

# %%
df_concat_9306.head()
# Out:
#   CO_ANO CO_MES CO_SH4                                         NO_SH4_POR  \
# 0   2023     05   9306  Bombas; granadas; torpedos; minas; mísseis; ca...
# 1   2023     05   9306  Bombas; granadas; torpedos; minas; mísseis; ca...
# 2   2023     02   9306  Bombas; granadas; torpedos; minas; mísseis; ca...
# 3   2023     03   9306  Bombas; granadas; torpedos; minas; mísseis; ca...
# 4   2023     04   9306  Bombas; granadas; torpedos; minas; mísseis; ca...
#
#      CO_NCM                                         NO_NCM_POR  \
# 0  93062100  Cartuchos para espingardas ou carabinas de can...
# 1  93062100  Cartuchos para espingardas ou carabinas de can...
# 2  93062100  Cartuchos para espingardas ou carabinas de can...
# 3  93062100  Cartuchos para espingardas ou carabinas de can...
# 4  93062100  Cartuchos para espingardas ou carabinas de can...
#
#                 NO_ISIC_SECAO SG_UF_NCM  \
# 0  Indústria de Transformação        SP
# 1  Indústria de Transformação        SP
# 2  Indústria de Transformação        SP
# 3  Indústria de Transformação        SP
# 4  Indústria de Transformação        SP
#
#                                           NO_URF2        LAT       LONG  \
# 0                                 PORTO DE SANTOS -23.966041 -46.301944
# 1                                 PORTO DE SANTOS -23.966041 -46.301944
# 2                                 PORTO DE SANTOS -23.966041 -46.301944
# 3  AEROPORTO INTERNACIONAL DE SAO PAULO/GUARULHOS -23.430573 -46.473043
# 4  AEROPORTO INTERNACIONAL DE SAO PAULO/GUARULHOS -23.430573 -46.473043
#
#                    NO_ISIC_CLASSE    VL_FOB    NO_VIA        TIPO  \
# 0  Fabricação de armas e munições  15969253  MARITIMA  EXPORTAÇÃO
# 1  Fabricação de armas e munições  11453234  MARITIMA  EXPORTAÇÃO
# 2  Fabricação de armas e munições    226929  MARITIMA  EXPORTAÇÃO
# 3  Fabricação de armas e munições    100853     AEREA  EXPORTAÇÃO
# 4  Fabricação de armas e munições     99680     AEREA  EXPORTAÇÃO
#
#                   NO_PAIS  KG_LIQUIDO SG_UNID CADEIA PRODUTIVA
# 0  Emirados Árabes Unidos     1419549   KGL             Bélica
# 1          Estados Unidos      731784   KGL             Bélica
# 2                  Suécia       16120   KGL             Bélica
# 3       Tcheca; República        1091   KGL             Bélica
# 4                   Chile        2710   KGL             Bélica

# %%
## Quanto é exportado do sku para um destino - Previsão de Demanda
      |destino|sku|kg|mes|
    
#### Qual volume de cada sku será transportado nos próximos meses (6 meses) - otimização
  # por qual via?
    # quantidade distribuida por via (origem-destino)
         |destino|sku|kg|mes|
        
#### Probabilidade do sku sair por determinada via nos próximos meses (6 meses)
  # por qual via?
    # probabilidade (origem-destino)
         |origem|destino|sku|mes|via|prob|

# %%
df_concat_9306.loc[df_concat_9306['CO_NCM']=='93062100']['NO_VIA'].unique()
# Out:
# array(['MARITIMA', 'AEREA', 'RODOVIARIA', 'FERROVIARIA', 'MEIOS PROPRIOS',
#        'EM MAOS', 'VICINAL FRONTEIRICO'], dtype=object)

# %%
# salvando base com as 9603 produto exp SJC
df_concat_9306.to_csv('base_hist_9306_URF.csv', index=False)
